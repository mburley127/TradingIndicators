# %%
### Library Import
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Import functions from MACD.ipynb
# %run /Users/mburley/TradingIndicators/Indicators/MACD.ipynb
# Import functions from RSI.ipynb
# %run /Users/mburley/TradingIndicators/Indicators/RSI.ipynb
# Import functions from MACD.ipynb
# %run /Users/mburley/TradingIndicators/Indicators/ADX.ipynb
# Import functions from MACD.ipynb
# %run /Users/mburley/TradingIndicators/Indicators/CCI.ipynb
# Out:
# [*********************100%%**********************]  2 of 2 completed
#         GOOG      AAPL
# 76  2.817904 -2.012186
# 77  2.886708 -2.024764
# 78  3.001849 -1.842427
# 79  2.806568 -1.609173
# 80  3.877199 -1.455151
# MACD values list:  {'AAPL': -1.455150763154336, 'GOOG': 3.877198677785202}
# [*********************100%%**********************]  2 of 2 completed
#          AAPL       GOOG
# 76  44.604314  54.166674
# 77  45.098037  56.715865
# 78  50.340826  69.758427
# 79  50.526311  58.240843
# 80  51.470090  73.171373
# RSI values list:  {'AAPL': 51.47008992708928, 'GOOG': 73.17137343972175}
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  2 of 2 completed
#            AAPL       GOOG
# 1585  17.782281  30.045724
# 1586  17.710187  29.043727
# 1587  15.865705  29.088272
# 1588  15.650624  28.264282
# 1589  16.206242  30.994245
# [*********************100%%**********************]  2 of 2 completed
# ...
